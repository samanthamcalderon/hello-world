# %% [markdown]
# <a href="https://colab.research.google.com/github/samanthamcalderon/hello-world/blob/main/Cali_Housing_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%file requirements.txt
# numpy
# matplotlib
# seaborn
# pandas
# scikit-learn
# Out:
# Overwriting requirements.txt

# %%
! pip install -r requirements.txt

# %%
import pandas as pd
